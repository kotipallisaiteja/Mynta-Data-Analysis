# %%
import pandas as pd
df=pd.read_csv("myntra_webscraping.csv")
df2=pd.read_csv("brands.csv")
df
# Out:
#      Unnamed: 0                                               name  stars  \
# 0             0                  Slim Fit Herringbone Casual Shirt    4.0
# 1             1  Pure Cotton Textured Self Design Slim Fit Opaq...    4.4
# 2             2  The Lifestyle Co Men Light Blue Solid Regular ...    4.1
# 3             3              Highlander Men Checked Slim Fit Shirt    4.3
# 4             4  Men Classic Tartan Checks Opaque Checked Casua...    NaN
# ..          ...                                                ...    ...
# 395         395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9
# 396         396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4
# 397         397              Men Standard Pure Cotton Casual Shirt    4.1
# 398         398            Men Maroon Slim Fit Cotton Casual Shirt    4.4
# 399         399               Twilight Mauve Slim Fit Casual Shirt    4.3
#
#     no_of_ratings    price   discount         sleeve          fit  \
# ...

# %%
df2
# Out:
#      Unnamed: 0                brands
# 0             0           RARE RABBIT
# 1             1             Powerlook
# 2             2            HIGHLANDER
# 3             3            HIGHLANDER
# 4             4           RARE RABBIT
# ..          ...                   ...
# 395         395                 iCome
# 396         396              Roadster
# 397         397                 iCome
# 398         398            HIGHLANDER
# 399         399  The Indian Garage Co
#
# [400 rows x 2 columns]

# %%
df3=pd.concat([df,df2],axis=1)

# %%
df3
# Out:
#      Unnamed: 0                                               name  stars  \
# 0             0                  Slim Fit Herringbone Casual Shirt    4.0
# 1             1  Pure Cotton Textured Self Design Slim Fit Opaq...    4.4
# 2             2  The Lifestyle Co Men Light Blue Solid Regular ...    4.1
# 3             3              Highlander Men Checked Slim Fit Shirt    4.3
# 4             4  Men Classic Tartan Checks Opaque Checked Casua...    NaN
# ..          ...                                                ...    ...
# 395         395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9
# 396         396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4
# 397         397              Men Standard Pure Cotton Casual Shirt    4.1
# 398         398            Men Maroon Slim Fit Cotton Casual Shirt    4.4
# 399         399               Twilight Mauve Slim Fit Casual Shirt    4.3
#
#     no_of_ratings    price   discount         sleeve          fit  \
# ...

# %%
df3.head()
# Out:
#    Unnamed: 0                                               name  stars  \
# 0           0                  Slim Fit Herringbone Casual Shirt    4.0
# 1           1  Pure Cotton Textured Self Design Slim Fit Opaq...    4.4
# 2           2  The Lifestyle Co Men Light Blue Solid Regular ...    4.1
# 3           3              Highlander Men Checked Slim Fit Shirt    4.3
# 4           4  Men Classic Tartan Checks Opaque Checked Casua...    NaN
#
#   no_of_ratings    price   discount         sleeve          fit  \
# 0   125 Ratings  â‚¹1494  (35% OFF)  Short Sleeves     Slim Fit
# 1    44 Ratings   â‚¹989  (45% OFF)   Long Sleeves     Slim Fit
# 2  6.8k Ratings   â‚¹614  (59% OFF)   Long Sleeves  Regular Fit
# 3  2.2k Ratings   â‚¹413  (77% OFF)   Long Sleeves     Slim Fit
# 4           NaN   â‚¹989  (67% OFF)   Long Sleeves  Regular Fit
#
#           collar  Unnamed: 0       brands
# 0  Spread Collar           0  RARE RABBIT
# 1  Spread Collar           1    Powerlook
# ...

# %%
df3.tail()
# Out:
#      Unnamed: 0                                              name  stars  \
# 395         395  Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9
# 396         396      Men Olive Green Slim Fit Cotton Casual Shirt    4.4
# 397         397             Men Standard Pure Cotton Casual Shirt    4.1
# 398         398           Men Maroon Slim Fit Cotton Casual Shirt    4.4
# 399         399              Twilight Mauve Slim Fit Casual Shirt    4.3
#
#     no_of_ratings   price   discount         sleeve          fit  \
# 395   640 Ratings  â‚¹539  (70% OFF)  Short Sleeves     Slim Fit
# 396  4.9k Ratings  â‚¹620  (73% OFF)   Long Sleeves     Slim Fit
# 397  4.1k Ratings  â‚¹671  (52% OFF)   Long Sleeves  Regular Fit
# 398  4.9k Ratings  â‚¹689  (70% OFF)   Long Sleeves     Slim Fit
# 399   706 Ratings  â‚¹674  (55% OFF)   Long Sleeves     Slim Fit
#
#             collar  Unnamed: 0                brands
# 395   Cuban Collar         395                 iCome
# ...

# %%
df3.dropna(axis=0,inplace=True)
df3
# Out:
#      Unnamed: 0                                               name  stars  \
# 0             0                  Slim Fit Herringbone Casual Shirt    4.0
# 1             1  Pure Cotton Textured Self Design Slim Fit Opaq...    4.4
# 2             2  The Lifestyle Co Men Light Blue Solid Regular ...    4.1
# 3             3              Highlander Men Checked Slim Fit Shirt    4.3
# 5             5     Classic Self Design Spread Collar Casual Shirt    4.4
# ..          ...                                                ...    ...
# 395         395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9
# 396         396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4
# 397         397              Men Standard Pure Cotton Casual Shirt    4.1
# 398         398            Men Maroon Slim Fit Cotton Casual Shirt    4.4
# 399         399               Twilight Mauve Slim Fit Casual Shirt    4.3
#
#      no_of_ratings    price   discount         sleeve          fit  \
# ...

# %%
df3.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df3
# Out:
#                                                   name  stars  no_of_ratings  \
# 0                    Slim Fit Herringbone Casual Shirt    4.0    125 Ratings
# 1    Pure Cotton Textured Self Design Slim Fit Opaq...    4.4     44 Ratings
# 2    The Lifestyle Co Men Light Blue Solid Regular ...    4.1   6.8k Ratings
# 3                Highlander Men Checked Slim Fit Shirt    4.3   2.2k Ratings
# 5       Classic Self Design Spread Collar Casual Shirt    4.4  12.6k Ratings
# ..                                                 ...    ...            ...
# 395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9    640 Ratings
# 396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4   4.9k Ratings
# 397              Men Standard Pure Cotton Casual Shirt    4.1   4.1k Ratings
# 398            Men Maroon Slim Fit Cotton Casual Shirt    4.4   4.9k Ratings
# 399               Twilight Mauve Slim Fit Casual Shirt    4.3    706 Ratings
#
# ...

# %%
df3['discount'] = df3['discount'].apply(lambda x: "(50% OFF)" if "Rs." in x else x)
df3
# Out:
#                                                   name  stars  no_of_ratings  \
# 0                    Slim Fit Herringbone Casual Shirt    4.0    125 Ratings
# 1    Pure Cotton Textured Self Design Slim Fit Opaq...    4.4     44 Ratings
# 2    The Lifestyle Co Men Light Blue Solid Regular ...    4.1   6.8k Ratings
# 3                Highlander Men Checked Slim Fit Shirt    4.3   2.2k Ratings
# 5       Classic Self Design Spread Collar Casual Shirt    4.4  12.6k Ratings
# ..                                                 ...    ...            ...
# 395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9    640 Ratings
# 396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4   4.9k Ratings
# 397              Men Standard Pure Cotton Casual Shirt    4.1   4.1k Ratings
# 398            Men Maroon Slim Fit Cotton Casual Shirt    4.4   4.9k Ratings
# 399               Twilight Mauve Slim Fit Casual Shirt    4.3    706 Ratings
#
# ...

# %%
df3.replace({
    'price':'[â‚¹,MRPâ‚¹]',
    'no_of_ratings': '[ Ratings]'
},'',regex=True,inplace=True)

# %%
df3
# Out:
#                                                   name  stars no_of_ratings  \
# 0                    Slim Fit Herringbone Casual Shirt    4.0           125
# 1    Pure Cotton Textured Self Design Slim Fit Opaq...    4.4            44
# 2    The Lifestyle Co Men Light Blue Solid Regular ...    4.1          6.8k
# 3                Highlander Men Checked Slim Fit Shirt    4.3          2.2k
# 5       Classic Self Design Spread Collar Casual Shirt    4.4         12.6k
# ..                                                 ...    ...           ...
# 395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9           640
# 396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4          4.9k
# 397              Men Standard Pure Cotton Casual Shirt    4.1          4.1k
# 398            Men Maroon Slim Fit Cotton Casual Shirt    4.4          4.9k
# 399               Twilight Mauve Slim Fit Casual Shirt    4.3           706
#
# ...

# %%
df3.replace({

    'no_of_ratings': '[k]'
},'',regex=True,inplace=True)

# %%
df3
# Out:
#                                                   name  stars no_of_ratings  \
# 0                    Slim Fit Herringbone Casual Shirt    4.0           125
# 1    Pure Cotton Textured Self Design Slim Fit Opaq...    4.4            44
# 2    The Lifestyle Co Men Light Blue Solid Regular ...    4.1           6.8
# 3                Highlander Men Checked Slim Fit Shirt    4.3           2.2
# 5       Classic Self Design Spread Collar Casual Shirt    4.4          12.6
# ..                                                 ...    ...           ...
# 395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9           640
# 396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4           4.9
# 397              Men Standard Pure Cotton Casual Shirt    4.1           4.1
# 398            Men Maroon Slim Fit Cotton Casual Shirt    4.4           4.9
# 399               Twilight Mauve Slim Fit Casual Shirt    4.3           706
#
# ...

# %%
import re
df3['no_of_ratings']=df3['no_of_ratings'].apply(lambda x: float(x)*1000 if re.findall(r"\d*\.\d*",x) else float(x))

# %%
df3['no_of_ratings']
# Out:
# 0        125.0
# 1         44.0
# 2       6800.0
# 3       2200.0
# 5      12600.0
#         ...
# 395      640.0
# 396     4900.0
# 397     4100.0
# 398     4900.0
# 399      706.0
# Name: no_of_ratings, Length: 334, dtype: float64

# %%
df3["price"]=df3['price'].astype("int")

# %%
df3.stars.unique()
# Out:
# array([4. , 4.4, 4.1, 4.3, 4.2, 4.8, 3.9, 3.4, 3.6, 3.8, 5. , 3.7, 4.6,
#        3.2, 2.6, 3.5, 2.5, 4.5, 2.8, 3. , 3.1])

# %%
df3.shape
# Out:
# (334, 9)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           334 non-null    object
#  1   stars          334 non-null    float64
#  2   no_of_ratings  334 non-null    float64
#  3   price          334 non-null    int64
#  4   discount       334 non-null    object
#  5   sleeve         334 non-null    object
#  6   fit            334 non-null    object
#  7   collar         334 non-null    object
#  8   brands         334 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 26.1+ KB

# %%
df3.describe()
# Out:
#             stars  no_of_ratings        price
# count  334.000000     334.000000   334.000000
# mean     4.116168    4087.299401   649.173653
# std      0.287334   11575.170664   266.422805
# min      2.500000       1.000000   242.000000
# 25%      4.000000      56.000000   519.500000
# 50%      4.200000     622.500000   614.500000
# 75%      4.300000    2600.000000   688.750000
# max      5.000000  107200.000000  2727.000000

# %%
df3.drop_duplicates()
# Out:
#                                                   name  stars  no_of_ratings  \
# 0                    Slim Fit Herringbone Casual Shirt    4.0          125.0
# 1    Pure Cotton Textured Self Design Slim Fit Opaq...    4.4           44.0
# 2    The Lifestyle Co Men Light Blue Solid Regular ...    4.1         6800.0
# 3                Highlander Men Checked Slim Fit Shirt    4.3         2200.0
# 5       Classic Self Design Spread Collar Casual Shirt    4.4        12600.0
# ..                                                 ...    ...            ...
# 395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9          640.0
# 396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4         4900.0
# 397              Men Standard Pure Cotton Casual Shirt    4.1         4100.0
# 398            Men Maroon Slim Fit Cotton Casual Shirt    4.4         4900.0
# 399               Twilight Mauve Slim Fit Casual Shirt    4.3          706.0
#
# ...

# %%
df3['brands'] = df3['brands'].str.upper()

# %%
df3
# Out:
#                                                   name  stars  no_of_ratings  \
# 0                    Slim Fit Herringbone Casual Shirt    4.0          125.0
# 1    Pure Cotton Textured Self Design Slim Fit Opaq...    4.4           44.0
# 2    The Lifestyle Co Men Light Blue Solid Regular ...    4.1         6800.0
# 3                Highlander Men Checked Slim Fit Shirt    4.3         2200.0
# 5       Classic Self Design Spread Collar Casual Shirt    4.4        12600.0
# ..                                                 ...    ...            ...
# 395   Slim Fit Cuban Collar Short Sleeves Casual Shirt    3.9          640.0
# 396       Men Olive Green Slim Fit Cotton Casual Shirt    4.4         4900.0
# 397              Men Standard Pure Cotton Casual Shirt    4.1         4100.0
# 398            Men Maroon Slim Fit Cotton Casual Shirt    4.4         4900.0
# 399               Twilight Mauve Slim Fit Casual Shirt    4.3          706.0
#
# ...

# %%
df3.to_csv("cleaned_myntra_df_for_BI.csv",index=False)
